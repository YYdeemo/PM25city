# %% [markdown]
# <table border="0" width="100%"><tr><td><p align="left"><img src="Images/logo.png" align="left" width="300"></p></td><td><font size="5"></font></td></tr></table>

# %% [markdown]
# # <center>第02部分 Pandas基础</center>

# %% [markdown]
# pandas是基于NumPy数组构建的，特别是基于数组的函数和不使用for循环的数据处理。
#
# 虽然pandas采用了大量的NumPy编码风格，但二者最大的不同是pandas是专门为处理表格和混杂数据设计的。而NumPy更适合处理统一的数值数组数据。

# %% [markdown]
# ## 1. pandas数据结构
# 要使用pandas，首先就得熟悉它的两个主要数据结构：<font color=red>Series</font>和<font color=red>DataFrame</font>。
# ### Series
# Series是一种类似于一维数组的对象，它由一组数据（各种NumPy数据类型）以及一组与之相关的数据标签（即索引）组成。仅由一组数据即可产生最简单的Series：

# %%
import pandas as pd

# %%
obj = pd.Series([4,7,-5,3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %% [markdown]
# Series的字符串表现形式为：索引在左边，值在右边。由于没有为数据指定索引，于是会<font color=red>自动创建一个0到N-1（N为数据的长度）的整数型索引</font>。可以通过Series 的values和index属性获取其数组表示形式和索引对象：

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
list(obj.index)
# Out:
# [0, 1, 2, 3]

# %% [markdown]
# 也可以使用特定的索引：

# %%
obj2 = pd.Series([5,2,-3,1], index=['d', 'b', 'c', 'a'])
obj2
# Out:
# d    5
# b    2
# c   -3
# a    1
# dtype: int64

# %% [markdown]
# 可以通过索引的方式选取Series中的单个或一组值：

# %%
obj2['a']
# Out:
# 1

# %%
obj2[['a','c','b']]
# Out:
# a    1
# c   -3
# b    2
# dtype: int64

# %% [markdown]
# 使用NumPy函数或类似NumPy的运算（如根据布尔型数组进行过滤、标量乘法、应用数学函数等）都会保留索引值的链接：

# %%
obj2 > 0
# Out:
# d     True
# b     True
# c    False
# a     True
# dtype: bool

# %%
obj2[obj2 > 0]
# Out:
# d    5
# b    2
# a    1
# dtype: int64

# %%
obj2 * 10
# Out:
# d    50
# b    20
# c   -30
# a    10
# dtype: int64

# %%
import numpy as np
np.sqrt(np.abs(obj2))
# Out:
# d    2.236068
# b    1.414214
# c    1.732051
# a    1.000000
# dtype: float64

# %% [markdown]
# 还可以将Series看成是一个定长的有序字典，因为它是索引值到数据值的一个映射。它可以用在许多原本需要字典参数的函数中：

# %% [markdown]
# # b in obj2 //判断'b'是否在<font color=red>索引</font>里面

# %%
'b' in obj2
# Out:
# True

# %%
'e' in obj2
# Out:
# False

# %% [markdown]
# 如果数据被存放在一个Python的字典中，也可以直接通过这个字典来创建Series：

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj3 = pd.Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %% [markdown]
# 如果只传入一个字典，则结果Series中的索引就是原字典的键（<font color=red>有序排列</font>）。你可以传入排好序的字典的键以改变顺序：

# %%
#在这个例子中，sdata中跟states索引相匹配的那3个值会被找出来并放到相应的位置上，
#但由于"California"所对应的sdata值找不到，
#所以其结果就为NaN（即“非数字”（not a number），在pandas中，它用于表示缺失或NA值）。
#因为‘Utah’不在states中，它被从结果中除去。

states = ['California', 'Oregon', 'Texas', 'Ohio']
obj4 = pd.Series(sdata, index=states)
obj4
# Out:
# California        NaN
# Oregon        16000.0
# Texas         71000.0
# Ohio          35000.0
# dtype: float64

# %% [markdown]
# pandas的<font color=red>isnull</font>和<font color=red>notnull</font>函数可用于检测缺失数据：

# %%
pd.isnull(obj4)
# Out:
# California     True
# Oregon        False
# Texas         False
# Ohio          False
# dtype: bool

# %%
pd.notnull(obj4)
# Out:
# California    False
# Oregon         True
# Texas          True
# Ohio           True
# dtype: bool

# %% [markdown]
# Series也有类似的实例方法：

# %%
obj4.isnull()
# Out:
# California     True
# Oregon        False
# Texas         False
# Ohio          False
# dtype: bool

# %% [markdown]
# 对于许多应用而言，Series最重要的一个功能是，<font color=red>它会根据运算的索引标签自动对齐数据</font>：

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj4
# Out:
# California        NaN
# Oregon        16000.0
# Texas         71000.0
# Ohio          35000.0
# dtype: float64

# %%
obj3 + obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %% [markdown]
# Series对象本身及其索引都有一个name属性，该属性跟pandas其他的关键功能关系非常密切：

# %%
obj4.name = 'population'
obj4.index.name = 'state'
obj4
# Out:
# state
# California        NaN
# Oregon        16000.0
# Texas         71000.0
# Ohio          35000.0
# Name: population, dtype: float64

# %%
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.index = ['Bob', 'Steve', 'Jeff', 'Ryan']
obj
# Out:
# Bob      4
# Steve    7
# Jeff    -5
# Ryan     3
# dtype: int64

# %% [markdown]
# ## .fillna(0,inplace=True) 对本身进行改，而不是创建了一个新的数据集

# %% [markdown]
# ### DataFrame
# DataFrame是一个表格型的数据结构，它含有一组有序的列，<font color=red>每列可以是不同的值类型（数值、字符串、布尔值等）</font>。DataFrame既有行索引也有列索引，它可以被看做由Series组成的字典（共用同一个索引）。DataFrame中的数据是以一个或多个二维块存放的（而不是列表、字典或别的一维数据结构）。
#
# 建DataFrame的办法有很多，最常用的一种是直接传入一个由等长列表或NumPy数组组成的字典：

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002, 2003],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)

# %% [markdown]
# 结果DataFrame会<font color=red>自动加上索引</font>（跟Series一样），且全部列会被有序排列：

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# 对于特别大的DataFrame，head方法会选取前五行：

# %%
frame.head(10)
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# 如果指定了列序列，则DataFrame的列就会按照指定顺序进行排列：

# %%
pd.DataFrame(data, columns=['year', 'state', 'pop'])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %% [markdown]
# 如果传入的列在数据中找不到，就会在结果中产生<font color=red>缺失值</font>：

# %%
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'],
                      index=['one', 'two', 'three', 'four','five', 'six'])
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %% [markdown]
# 通过类似字典标记的方式或属性的方式，可以将DataFrame的列获取为一个Series：

# %%
frame2['state']
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
frame.year

# %% [markdown]
# 注意，返回的Series拥有原DataFrame相同的索引，且其name属性也已经被相应地设置好了。
#
# <font color=red>行</font>也可以通过位置或名称的方式进行获取，比如用loc属性

# %%
frame2.loc['three']
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: three, dtype: object

# %% [markdown]
# 列可以通过赋值的方式进行修改。例如，可以给那个空的"debt"列赋上一个标量值或一组值：

# %%
frame2['debt'] = 16.5
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5  16.5
# two    2001    Ohio  1.7  16.5
# three  2002    Ohio  3.6  16.5
# four   2001  Nevada  2.4  16.5
# five   2002  Nevada  2.9  16.5
# six    2003  Nevada  3.2  16.5

# %%
import numpy as np
frame2['debt'] = np.arange(6.)
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   0.0
# two    2001    Ohio  1.7   1.0
# three  2002    Ohio  3.6   2.0
# four   2001  Nevada  2.4   3.0
# five   2002  Nevada  2.9   4.0
# six    2003  Nevada  3.2   5.0

# %% [markdown]
# 将列表或数组赋值给某个列时，<font color=red>其长度必须跟DataFrame的长度相匹配</font>。如果赋值的是一个Series，就会<font color=red>精确匹配DataFrame的索引</font>，所有的空位都将被填上缺失值：

# %%
val = pd.Series([-1.2, -1.5, -1.7], index=['two', 'four', 'five'])
frame2['debt'] = val
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN

# %% [markdown]
# 为不存在的列赋值会创建出一个新列。关键字del用于删除列。
#
# 作为del的例子，先添加一个新的布尔值的列，state是否为'Ohio'：

# %%
frame2['eastern'] = frame2.state == 'Ohio'
frame2
# Out:
#        year   state  pop  debt  eastern
# one    2000    Ohio  1.5   NaN     True
# two    2001    Ohio  1.7  -1.2     True
# three  2002    Ohio  3.6   NaN     True
# four   2001  Nevada  2.4  -1.5    False
# five   2002  Nevada  2.9  -1.7    False
# six    2003  Nevada  3.2   NaN    False

# %%
del frame2['eastern']
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN

# %% [markdown]
# 注意：通过索引方式返回的列只是相应<font color=red>数据的视图</font>而已，并不是副本。因此，对返回的Series所做的任何就地修改全都会反映到源DataFrame上。通过Series的copy方法即可指定复制列。
#
# 另一种常见的数据形式是<font color=red>嵌套字典</font>：

# %%
pop1 = {'Nevada': {2001: 2.4, 2002: 2.9},
        'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}}

# %% [markdown]
# 如果嵌套字典传给DataFrame，pandas就会被解释为：<font color=red>外层字典的键作为列，内层键则作为行索引</font>：

# %%
frame3 = pd.DataFrame(pop1)
frame3
# Out:
#       Nevada  Ohio
# 2000     NaN   1.5
# 2001     2.4   1.7
# 2002     2.9   3.6

# %% [markdown]
# 也可以使用类似NumPy数组的方法，对DataFrame进行转置（交换行和列）：

# %%
frame3.T
# Out:
#         2000  2001  2002
# Nevada   NaN   2.4   2.9
# Ohio     1.5   1.7   3.6

# %% [markdown]
# 内层字典的键会被合并、排序以形成最终的索引。如果明确指定了索引，则不会这样：

# %%
pd.DataFrame(pop, index=[2001, 2002, 2003])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-84df27ae30f4> in <module>()
# ----> 1 pd.DataFrame(pop, index=[2001, 2002, 2003])
#
# NameError: name 'pop' is not defined

# %% [markdown]
# 由Series组成的字典差不多也是一样的用法：

# %%
type(frame3['Ohio'][:2])

# %%
pdata = {'Ohio': frame3['Ohio'][:-1],
         'Nevada': frame3['Nevada'][:2]}
pd.DataFrame(pdata)

# %% [markdown]
# 表5-1列出了DataFrame构造函数所能接受的各种数据。
# ![image.png](attachment:image.png)

# %% [markdown]
# 如果设置了DataFrame的index和columns的name属性，则这些信息也会被显示出来：

# %%
frame3.index.name = 'year'
frame3.columns.name = 'state'
frame3

# %% [markdown]
# 跟Series一样，values属性也会以二维ndarray的形式返回DataFrame中的数据：

# %%
frame3.values

# %% [markdown]
# 如果DataFrame各列的数据类型不同，由于numpy数组存储的数据类型需要一致，则值数组的dtype就<font color=red>会选用能兼容所有列的数据类型</font>：

# %%
frame2.values

# %% [markdown]
# ### 索引对象
# pandas的索引对象负责管理轴标签和其他元数据（比如轴名称等）。构建Series或DataFrame时，所用到的任何数组或其他序列的标签都会被转换成一个Index：

# %%
obj = pd.Series(range(3), index=['a', 'b', 'c'])
index = obj.index
index

# %%
index[1:]

# %% [markdown]
# Index对象是不可变的，因此用户不能对其进行修改：

# %%
index[1] = 'd'

# %% [markdown]
# 不可变可以使Index对象在多个数据结构之间<font color=red>安全共享</font>：

# %%
labels = pd.Index(np.arange(3))
labels

# %%
obj2 = pd.Series([1.5, -2.5, 0], index=labels)
obj2

# %%
obj2.index is labels

# %%
obj3 = pd.Series(['a', 'b', 'c'], index=labels)
obj3

# %%
obj3.index is labels

# %% [markdown]
# 除了类似于数组，Index的功能也类似一个固定大小的集合：

# %%
frame3

# %%
frame3.columns

# %% [raw]
# 'Ohio' in frame3.columns

# %%
2003 in frame3.index

# %% [markdown]
# 与python的集合不同，<font color=red>pandas的Index可以包含重复的标签</font>：

# %%
dup_labels = pd.Index(['foo', 'foo', 'bar', 'bar'])
dup_labels

# %% [markdown]
# 选择重复的标签，会显示所有的结果。
#
# 每个索引都有一些方法和属性，它们可用于设置逻辑并回答有关该索引所包含的数据的常见问题。表5-2列出了这些函数。
# ![image.png](attachment:image.png)

# %%
import pandas as pd
fileName1 = 'Documents/员工信息表.csv'
fileName2 = 'Documents/income.csv'

def readFromCSV(fileName):
    with open(fileName) as f1:
        columns = f1.readline().strip().split(',')[1:]
        valuesDic = {}
        for col in columns:
            valuesDic[col] = {}
        for line in f1:
            info = line.strip().split(',') 
            for i, item in enumerate(columns):
                valuesDic[item][info[0]] = info[i+1]
    return pd.DataFrame(valuesDic)
empInfoDF = readFromCSV(fileName1)
incomeDF = readFromCSV(fileName2)
empInfoDF.head(3)

# %%
incomeDF.head(3)

# %% [markdown]
# ## 2 基本功能
# ### 重新索引
# pandas对象的一个重要方法是reindex，其作用是创建一个新对象，它的数据符合新的索引。看下面的例子：

# %%
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=['d', 'b', 'a', 'c'])
obj

# %% [markdown]
# 用该Series的reindex将会根据新索引进行重排。如果某个索引值当前不存在，就引入缺失值：

# %%
obj2 = obj.reindex(['a', 'b', 'c', 'd', 'e'])
obj2

# %% [markdown]
# ### 课堂练习：
# 1. 将empInfoDF中的姓名列存在empNameSeries中
# 2. 根据编号的倒序进行重新索引

# %% [markdown]
# 对于时间序列这样的有序数据，重新索引时可能需要做一些插值处理。method选项即可达到此目的，例如，使用ffill可以实现前向值填充：

# %%
obj3 = pd.Series(['blue', 'purple', 'yellow'], index=[0, 2, 4])
obj3

# %%
obj3.reindex(range(6), method='ffill')

# %% [markdown]
# ### 课堂练习
# 1. 获取600001在2019年05月08日至2019年05月20日的股票开盘数据
# 2. 对于缺少开盘数据的日期：05月11日和05月12日，利用05月10日的数据填充

# %%
import tushare as ts
stockDF = ts.get_hist_data('601318',start='2019-05-08',end='2019-05-20')
stockDF

# %% [markdown]
# 借助DataFrame，reindex可以修改（行）索引和列。只传递一个序列时，会重新索引结果的行：

# %%
frame = pd.DataFrame(np.arange(9).reshape((3,3)), index=['a', 'c', 'd'], columns=['Ohio', 'Texas', 'California'])
frame

# %%
frame2 = frame.reindex(['a', 'b', 'c', 'd'])
frame2

# %% [markdown]
# 列可以用columns关键字重新索引：

# %%
states = ['Texas', 'Utah', 'California']
frame.reindex(columns = states)

# %% [markdown]
# ### 课堂练习
# 1. 按照：姓名，基本工资，奖金，住房补助，五险一金，专项附加扣除，其他扣款的顺序调整incomeDF的列

# %% [markdown]
# 表5-3列出了reindex函数的各参数及说明。
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 丢弃指定轴上的项
# 丢弃某条轴上的一个或多个项很简单，只要有一个索引数组或列表即可。由于需要执行一些数据整理和集合逻辑，所以drop方法返回的是一个在指定轴上删除了指定值的新对象：

# %%
obj = pd.Series(np.arange(5.), index = ['a', 'b', 'c', 'd', 'e'])
obj

# %%
new_obj = obj.drop('c')
new_obj

# %%
obj.drop(['d', 'c'])

# %%
obj

# %% [markdown]
# ### 课堂练习
# 1. 删除empInfoDF中10941和10946的数据

# %% [markdown]
# 对于DataFrame，可以删除任意轴上的索引值。为了演示，先新建一个DataFrame例子：

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=['Ohio', 'Colorado', 'Utah', 'New York'],
                    columns=['one', 'two', 'three', 'four'])
data

# %% [markdown]
# 用标签序列调用drop会从行标签（axis 0）删除值：

# %%
data.drop(['Colorado', 'Ohio'])

# %% [markdown]
# 通过传递axis=1或axis='columns'可以删除列的值：

# %%
data.drop('two', axis = 1)

# %%
data.drop(['two', 'four'], axis='columns')

# %%
data

# %% [markdown]
# ### 课堂练习
# 1. 删除empInfoDF中的部门和电子邮箱列

# %% [markdown]
# 许多函数带有<font color=red>inplace</font>参数，如drop，会修改Series或DataFrame的大小或形状，可以就地修改对象，不会返回新的对象：

# %%
obj.drop('c', inplace=True)
obj

# %%
obj

# %% [markdown]
# <font color=red>小心使用inplace，它会销毁所有被删除的数据。</font>

# %% [markdown]
# ### 索引、选取和过滤
# Series索引（obj[...]）的工作方式类似于NumPy数组的索引，只不过Series的索引值不只是整数。下面是几个例子：

# %%
import pandas as pd
import numpy as np
obj = pd.Series(np.arange(4.), index=['a', 'b', 'c', 'd'])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj['b']
# Out:
# 1.0

# %%
#获取stockDF中2019-05-15的开盘价

# %%
obj[1]

# %%
obj[2:4]

# %%
# 获取前面5个员工的姓名

# %%
obj[['b', 'a', 'd']]
# Out:
# b    1.0
# a    0.0
# d    3.0
# dtype: float64

# %%
# 获取stockDF中2019-05-15, 2019-05-18和2019-05-20的收盘价

# %%
obj[[1,3]]

# %%
obj[obj < 2]
# Out:
# a    0.0
# b    1.0
# dtype: float64

# %%
#获取empInfoDF部门为管理的员工姓名

# %% [markdown]
# 利用标签的切片运算与普通的Python切片运算不同，<font color=red>其末端是包含的</font>：

# %%
obj['b':'c']

# %%
#获取stockDF中2019-05-10至2019-05-15的每天最高价数据

# %% [markdown]
# 用切片可以对Series的相应部分进行设置：

# %%
obj['b':'c'] = 5
obj

# %% [markdown]
# 用一个值或序列对DataFrame进行索引其实就是获取一个或多个列：

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=['Ohio', 'Colorado', 'Utah', 'New York'],
                    columns=['one', 'two', 'three', 'four'])

# %%
data

# %%
data['two']

# %%
data[['three', 'one']]

# %%
#获取empInfoDF中的姓名和电子邮箱

# %% [markdown]
# 这种索引方式有几个特殊的情况。首先通过<font color=red>切片或布尔型数组</font>选取数据：

# %%
data[:2]

# %%
data[data['three'] > 5]
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# <font color=red>选取行</font>的语法data[:2]十分方便。向[ ]传递单一的元素或列表，就可<font color=red>选择列</font>。

# %%
#查看stockDF中开盘价大于收盘价的股票数据

# %% [markdown]
# 另一种用法是通过布尔型DataFrame（比如下面这个由标量比较运算得出的）进行索引：

# %%
data < 5
# Out:
#             one    two  three   four
# Ohio       True   True   True   True
# Colorado   True  False  False  False
# Utah      False  False  False  False
# New York  False  False  False  False

# %%
data[data<5]
# Out:
#           one  two  three  four
# Ohio      0.0  1.0    2.0   3.0
# Colorado  4.0  NaN    NaN   NaN
# Utah      NaN  NaN    NaN   NaN
# New York  NaN  NaN    NaN   NaN

# %%
data[data < 5] = 0
data

# %% [markdown]
# ### 用loc和iloc进行选取
# 对于DataFrame的行的标签索引，引入了特殊的标签运算符loc和iloc。它们可以让你用类似NumPy的标记，使用轴标签（loc）或整数索引（iloc），从DataFrame选择行和列的子集。
#
# 作为一个初步示例，让我们通过标签选择一行和多列：

# %%
data

# %%
data.loc['Colorado', ['two', 'three']]

# %%
type(data.loc['Colorado', ['two', 'three']])

# %%
#通过标签选择10936的姓名，基本工资和住房补助

# %%
data.iloc[2,[3,0,1]]

# %%
data.iloc[2]

# %%
data.iloc[[1,2], [3,0,1]]

# %%
#通过整数索引选择10933和10936的姓名、基本工资、奖金和住房补助

# %% [markdown]
# 这两个索引函数也适用于一个标签或多个标签的切片：

# %%
data.loc[:'Utah', 'two']

# %%
data.iloc[:, :3][data.three > 5]

# %%
#获取stockDF中成交量大volume于850000的开盘价、最高价、收盘价和最低价

# %% [markdown]
# 在pandas中，有多个方法可以选取和重新组合数据。对于DataFrame，表5-4进行了总结。
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 整数索引
# 处理整数索引的pandas对象常常难住新手，因为它与Python内置的列表和元组的索引语法不同。例如，你可能不认为下面的代码会出错：

# %%
ser = pd.Series(np.arange(3.0))
ser

# %%
ser[2]

# %%
ser[-1]

# %% [markdown]
# 这里，pandas可以勉强进行整数索引，但是会导致小bug。我们有包含0,1,2的索引，但是引入用户想要的东西（基于标签或位置的索引）很难，另外，对于非整数索引，不会产生歧义：

# %%
ser2 = pd.Series(np.arange(3.), index=['a', 'b', 'c'])
ser2[-1]

# %% [markdown]
# 为了进行统一，如果轴索引含有整数，数据选取总会使用标签。为了更准确，请使用loc（标签）或iloc（整数）：

# %%
ser

# %%
ser[:1]

# %%
ser.loc[:1]

# %%
ser.iloc[:1]

# %% [markdown]
# <font color=red>注意区分以上三个语句的结果</font>

# %% [markdown]
# ### 算术运算和数据对齐
# pandas最重要的一个功能是，它可以对不同索引的对象进行算术运算。在将对象相加时，如果存在不同的索引对，则结果的索引就是该索引对的并集。对于有数据库经验的用户，这就像在索引标签上进行自动外连接。看一个简单的例子：

# %%
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=['a', 'c', 'd', 'e'])

# %%
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1], index=['a', 'c', 'e', 'f', 'g'])

# %%
s1

# %%
s2

# %% [markdown]
# 将它们相加，自动的数据对齐操作在不重叠的索引处引入了NA值。缺失值会在算术运算过程中传播。

# %%
s1 + s2

# %%
#计算incomeDF中每个人的收入和支出（直接相加得不到想要的结果，可能需要用到后面的apply函数）
incomeDF['收入'] = incomeDF.基本工资 + incomeDF.奖金 + incomeDF.住房补助
incomeDF['支出'] = incomeDF.五险一金 + incomeDF.专项附加扣除 + incomeDF.其他扣款
incomeDF

# %% [markdown]
# 对于DataFrame，对齐操作会同时发生在行和列上：

# %%
df1 = pd.DataFrame(np.arange(9.0).reshape((3,3)), columns=list('bcd'),
                   index = ['Ohio', 'Texas', 'Colorado'])
df2 = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list('bde'),
                   index=['Utah', 'Ohio', 'Texas', 'Oregon'])

# %%
df1

# %%
df2

# %% [markdown]
# 把它们相加后将会返回一个新的DataFrame，其索引和列为原来那两个DataFrame的并集：

# %%
df1 + df2

# %% [markdown]
# 如果DataFrame对象相加，没有共用的列或行标签，结果都会是空：

# %%
df1 = pd.DataFrame({'A':[1,2]})
df2 = pd.DataFrame({'B':[3,4]})

# %%
df1

# %%
df2

# %%
df1 - df2

# %% [markdown]
# ### 课堂练习
# 1. 删除incomeDF中的姓名列，保存在everyMonthIncomeDF中
# 2. 计算两个月的收入情况

# %% [markdown]
# ### 在算术方法中填充值
# 在对不同索引的对象进行算术运算时，你可能希望当一个对象中某个轴标签在另一个对象中找不到时填充一个特殊值（比如0）：

# %%
df1 = pd.DataFrame(np.arange(12.).reshape((3, 4)),
                   columns=list('abcd'))
df2 = pd.DataFrame(np.arange(20.).reshape((4, 5)),
                   columns=list('abcde'))

# %%
df2.loc[1, 'b'] = np.nan

# %%
df1

# %%
df2

# %% [markdown]
# 将它们相加时，没有重叠的位置就会产生NA值：

# %%
df1 + df2

# %% [markdown]
# 使用df1的add方法，传入df2以及一个fill_value参数：

# %%
df1.add(df2, fill_value=0)

# %% [markdown]
# 下表列出了Series和DataFrame的算术方法。
#
# ![image.png](attachment:image.png)
#
# 它们每个都有一个副本，以字母r开头，它会翻转参数。因此这两个语句是等价的：

# %%
1 / df1

# %%
df1.rdiv(1)

# %% [markdown]
# 与此类似，在对Series或DataFrame重新索引时，也可以指定一个填充值：

# %%
df1.reindex(columns=df2.columns, fill_value=0)

# %% [markdown]
# ### DataFrame和Series之间的运算
# 跟不同维度的NumPy数组一样，DataFrame和Series之间算术运算也是有明确规定的。先来看一个具有启发性的例子，计算一个二维数组与其某行之间的差：

# %%
arr = np.arange(12.).reshape((3,4))
arr

# %%
arr[0]

# %%
print(arr[0].shape)

# %%
arr - arr[0]

# %% [markdown]
# 当我们从arr减去arr[0]，每一行都会执行这个操作。这就叫做广播（broadcasting）。DataFrame和Series之间的运算差不多也是如此：

# %%
frame = pd.DataFrame(np.arange(12.).reshape((4, 3)),
                     columns=list('bde'),
                     index=['Utah', 'Ohio', 'Texas', 'Oregon'])
series = frame.iloc[0]

# %%
frame

# %%
series

# %% [markdown]
# 默认情况下，DataFrame和Series之间的算术运算会将Series的索引匹配到DataFrame的列，然后沿着行一直向下广播：

# %%
frame - series

# %% [markdown]
# 如果某个索引值在DataFrame的列或Series的索引中找不到，则参与运算的两个对象就会被重新索引以形成并集：

# %%
series2 = pd.Series(range(3), index=['b','e','f'])
series2

# %%
frame + series2

# %% [markdown]
# 如果你希望匹配行且在列上广播，则必须使用<font color=red>算术运算方法</font>。例如：

# %%
series3 = frame['d']
frame

# %%
series3

# %%
frame.sub(series3, axis='index')

# %% [markdown]
# 传入的轴号就是希望匹配的轴。在本例中，我们的目的是匹配DataFrame的行索引（axis='index' or axis=0）并进行广播。

# %% [markdown]
# ### 函数应用和映射
# NumPy的ufuncs（元素级数组方法）也可用于操作pandas对象：

# %%
frame = pd.DataFrame(np.random.randn(4, 3), columns=list('bde'),
                     index=['Utah', 'Ohio', 'Texas', 'Oregon'])
frame

# %%
np.abs(frame)

# %% [markdown]
# 另一个常见的操作是，将函数应用到由各列或行所形成的一维数组上。DataFrame的apply方法即可实现此功能：

# %%
f = lambda x: x.max() - x.min()
frame.apply(f)

# %% [markdown]
# 这里的函数f，计算了一个Series的最大值和最小值的差，在frame的每列都执行了一次。结果是一个Series，使用frame的列作为索引。
#
# 如果传递axis='columns'到apply，这个函数会在每行执行：

# %%
frame.apply(f, axis='columns')

# %% [markdown]
# 许多最为常见的数组统计功能都被实现成DataFrame的方法（如sum和mean），因此无需使用apply方法。
#
# 传递到apply的函数不是必须返回一个标量，还可以返回由多个值组成的Series：

# %%
def f(x):
    return pd.Series([x.min(), x.max()], index=['min', 'max'])

frame.apply(f)

# %% [markdown]
# <font color=red>元素级的</font>Python函数也是可以用的。假如你想得到frame中各个浮点值的格式化字符串，使用applymap即可：

# %%
formater = lambda x: '%.2f' % x
frame.applymap(formater)

# %% [markdown]
# 之所以叫做applymap，是因为Series有一个用于应用元素级函数的map方法：

# %%
frame['e'].map(formater)

# %% [markdown]
# ### 课堂练习
# 1. 给所有人的奖金增加1000元

# %% [markdown]
# ### 排序和排名
# 根据条件对数据集排序（sorting）也是一种重要的内置运算。要对行或列索引进行排序（按字典顺序），可使用sort_index方法，它将返回一个已排序的新对象：

# %%
obj = pd.Series(range(4), index=['d', 'a', 'b','c'])
obj.sort_index()

# %% [markdown]
# 对于DataFrame，则可以根据任意一个轴上的索引进行排序：

# %%
frame = pd.DataFrame(np.arange(8).reshape((2, 4)),
                     index=['three', 'one'],
                     columns=['d', 'a', 'b', 'c'])

# %%
frame.sort_index()

# %%
frame.sort_index(axis=1)

# %% [markdown]
# 数据默认是按升序排序的，但也可以降序排序：

# %%
frame.sort_index(axis=1, ascending=False)

# %% [markdown]
# 若要按值对Series进行排序，可使用其sort_values方法：

# %%
obj = pd.Series([4, 7, -3, 2])
obj.sort_values()

# %% [markdown]
# 在排序时，任何缺失值默认都会被放到Series的末尾：

# %%
obj = pd.Series([4, np.nan, 7, np.nan, -3, 2])
obj.sort_values()

# %% [markdown]
# 当排序一个DataFrame时，你可能希望根据一个或多个列中的值进行排序。将一个或多个列的名字传递给sort_values的by选项即可达到该目的：

# %%
frame = pd.DataFrame({'b': [4, 7, -3, 2], 'a':[0, 1, 0, 1]})
frame

# %%
frame.sort_values(by='b')

# %% [markdown]
# 要根据多个列进行排序，传入名称的列表即可：

# %%
frame.sort_values(by=['a', 'b'])

# %% [markdown]
# ### 课堂练习
# 1. 按照日期的升序对stockDF进行排序
# 2. 对incomeDF按照奖金的降序进行排序，在奖金相同的情况下，按照基本工资的升序进行排序

# %% [markdown]
# 排名会从1开始一直到数组中有效数据的数量。
#
# 接下来介绍Series和DataFrame的rank方法。默认情况下，rank是通过“为各组分配一个平均排名”的方式破坏平级关系的：

# %%
obj = pd.Series([7, -5, 7, 4, 2, 0, 4])
obj.rank()

# %% [markdown]
# 也可以根据值在原数据中出现的顺序给出排名：

# %%
obj.rank(method='first')

# %% [markdown]
# 这里，条目0和2没有使用平均排名6.5，它们被设成了6和7，因为数据中标签0位于标签2的前面。
#
# 你也可以按降序进行排名：

# %%
obj.rank(ascending=False, method='max')

# %% [markdown]
# DataFrame可以在行或列上计算排名：

# %%
frame = pd.DataFrame({'b': [4.3, 7, -3, 2], 'a': [0, 1, 0, 1],
                      'c': [-2, 5, 8, -2.5]})
frame

# %%
frame.rank(axis='columns')

# %%
frame.rank()

# %% [markdown]
# 下表列出了所有用于破坏平级关系的method选项：
# ![image.png](attachment:image.png)

# %%
incomeDF.rank()

# %% [markdown]
# ### 带有重复标签的轴索引
# 直到目前为止，所介绍的所有范例都有着唯一的轴标签（索引值）。虽然许多pandas函数（如reindex）都要求标签唯一，但这并不是强制性的。我们来看看下面这个简单的带有重复索引值的Series：

# %%
obj = pd.Series(range(5), index=['a', 'a', 'b', 'b', 'c'])
obj

# %% [markdown]
# 索引的is_unique属性可以告诉你它的值是否是唯一的：

# %%
obj.index.is_unique

# %% [markdown]
# 对于带有重复值的索引，数据选取的行为将会有些不同。如果某个索引对应多个值，则返回一个Series；而对应单个值的，则返回一个标量值：

# %%
obj['a']

# %%
obj['c']

# %% [markdown]
# 这样会使代码变复杂，因为索引的输出类型会根据标签是否有重复发生变化。
#
# 对DataFrame的行进行索引时也是如此：

# %%
df = pd.DataFrame(np.random.randn(4, 3), index=['a', 'a', 'b', 'b'])
df

# %%
df.loc['b']

# %% [markdown]
# ## 3. 汇总和计算描述统计
# pandas对象拥有一组常用的数学和统计方法。它们大部分都属于约简和汇总统计，用于从Series中提取单个值（如sum或mean）或从DataFrame的行或列中提取一个Series。跟对应的NumPy数组方法相比，它们都是基于没有缺失数据的假设而构建的。看一个简单的DataFrame：

# %%
df = pd.DataFrame([[1.4, np.nan], [7.1, -4.5],
                   [np.nan, np.nan], [0.75, -1.3]],
                  index = ['a', 'b', 'c', 'd'],
                  columns=['one','two'])
df

# %% [markdown]
# 调用DataFrame的sum方法将会返回一个含有列的和的Series：

# %%
df.sum()

# %% [markdown]
# ### 课堂练习
# 1. 计算incomeDF中各列的平均值

# %% [markdown]
# 传入axis='columns'或axis=1将会按行进行求和运算：

# %%
df.sum(axis=1)

# %% [markdown]
# NA值会自动被排除，除非整个切片（这里指的是行或列）都是NA。通过skipna选项可以禁用该功能：

# %%
df.mean(axis='columns', skipna=False)

# %% [markdown]
# 表5-7列出了这些约简方法的常用选项。
# ![image.png](attachment:image.png)

# %% [markdown]
# 有些方法（如idxmin和idxmax）返回的是间接统计（比如达到最小值或最大值的索引）：

# %%
df.idxmax()

# %% [markdown]
# ### 课堂练习
# 1. 找出基本工资最高的人

# %%
incomeDF.loc[incomeDF.基本工资.idxmax()]

# %% [markdown]
# 另一些方法则是累计型的：

# %%
df.cumsum()

# %% [markdown]
# 还有一种方法，它既不是约简型也不是累计型。describe就是一个例子，它用于一次性产生多个汇总统计：

# %%
df.describe()

# %% [markdown]
# 对于非数值型数据，describe会产生另外一种汇总统计：

# %%
obj = pd.Series(['a', 'a', 'b', 'c'] * 4)
obj

# %%
obj.describe()

# %% [markdown]
# 表5-8列出了所有与描述统计相关的方法。
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 相关系数与协方差
# 有些汇总统计（如相关系数和协方差）是通过参数对计算出来的。我们来看几个DataFrame，它们的数据来自Yahoo!Finance的股票价格和成交量，使用的是pandas-datareader包（可以用conda或pip安装）：

# %%
import pandas as pd
import pandas_datareader.data as web
all_data = {ticker: web.get_data_yahoo(ticker)
            for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG']}

price = pd.DataFrame({ticker: data['Adj Close']
                     for ticker, data in all_data.items()})
volume = pd.DataFrame({ticker: data['Volume']
                      for ticker, data in all_data.items()})

# %%
all_data.items()
for ticker, data in all_data.items():
    print(ticker)
    print(type(data['Volume']))

# %%
price.head()

# %%
volume.head()

# %% [markdown]
# 现在计算价格的百分数变化：

# %%
returns = price.pct_change()
returns.tail()
returns.head()

# %% [markdown]
# Series的corr方法用于计算两个Series中重叠的、非NA的、按索引对齐的值的相关系数。与此类似，cov用于计算协方差：

# %%
returns['MSFT'].corr(returns['IBM'])

# %%
returns['MSFT'].cov(returns['IBM'])

# %% [markdown]
# 因为MSTF是一个合理的Python属性，我们还可以用更简洁的语法选择列：

# %%
returns.MSFT.corr(returns.IBM)

# %% [markdown]
# 另一方面，DataFrame的corr和cov方法将以DataFrame的形式分别返回完整的相关系数或协方差矩阵：

# %%
returns.corr()

# %%
returns.cov()

# %% [markdown]
# 利用DataFrame的corrwith方法，你可以计算其列或行跟另一个Series或DataFrame之间的相关系数。传入一个Series将会返回一个相关系数值Series（针对各列进行计算）：

# %%
returns.corrwith(returns.IBM)

# %% [markdown]
# 传入一个DataFrame则会计算按列名配对的相关系数。这里，计算百分比变化与成交量的相关系数：

# %%
returns.corrwith(volume)

# %% [markdown]
# 传入axis='columns'即可按行进行计算。无论如何，在计算相关系数之前，所有的数据项都会按标签对齐。

# %% [markdown]
# ### 唯一值、值计数以及成员资格
# 还有一类方法可以从一维Series的值中抽取信息。看下面的例子：

# %%
obj = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])

# %% [markdown]
# 第一个函数是unique，它可以得到Series中的唯一值数组：

# %%
uniques = obj.unique()
uniques

# %% [markdown]
# 返回的唯一值是未排序的，如果需要的话，可以对结果再次进行排序（uniques.sort()）。相似的，value_counts用于计算一个Series中各值出现的频率：

# %%
pd.value_counts(obj.values, sort=False)

# %% [markdown]
# isin用于判断矢量化集合的成员资格，可用于过滤Series中或DataFrame列中数据的子集：

# %%
obj

# %%
mask = obj.isin(['b', 'c'])
mask

# %%
obj[mask]

# %% [markdown]
# 与isin类似的是Index.get_indexer方法，它可以给你一个索引数组，从可能包含重复值的数组到另一个不同值的数组：

# %%
to_match = pd.Series(['c', 'a', 'b', 'b', 'c', 'a'])
unique_vals = pd.Series(['c', 'b' ,'a'])
pd.Index(unique_vals).get_indexer(to_match)

# %% [markdown]
# 下表给出了这几个方法的一些参考信息：
# ![image.png](attachment:image.png)

# %% [markdown]
# 有时，你可能希望得到DataFrame中多个相关列的一张柱状图。例如：

# %%
data = pd.DataFrame({'Qu1': [1, 3, 4, 3, 4],
                     'Qu2': [2, 3, 1, 2, 3],
                     'Qu3': [1, 5, 2, 4, 4]})
data

# %% [markdown]
# 将pandas.value_counts传给该DataFrame的apply函数，就会出现：

# %%
result = data.apply(pd.value_counts).fillna(0)
result

# %% [markdown]
# 这里，<font color=red>结果中的行标签是所有列的唯一值</font>。后面的频率值是每个列中这些值的相应计数。
